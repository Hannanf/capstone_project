# %% [markdown]
# In this section we will be scraping data from a website to show the avergae income by age in the US. This data will then be converted into a Pandas DataFrame and exported as a .csv file. The purpose of this table will be to provide additional data for our model

# %%
# Import libraries for scraping 
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

import pandas as pd

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Visit website to extract data (https://fourpillarfreedom.com/visualizing-the-income-of-americans-by-age/)
url = 'https://dqydj.com/income-percentile-by-age-calculator/'
page = browser.visit(url)
# Optional delay for loading the page
browser.is_element_present_by_css('div.list_text', wait_time=1)
# Out:
# False

# %%
html = browser.html

news_soup = soup(html, 'html.parser')
slide_elem = news_soup.select_one('div.list_text')

# %%
income_age_df = pd.read_html('https://dqydj.com/income-percentile-by-age-calculator/')[0]
income_age_df.columns=['Age', '25%', '50%', '75%', '90%', '99%', 'Average%']
income_age_df.set_index('Age', inplace=True)

income_age_df = df.iloc[1: , :]

income_age_df
# Out:
#          25%      50%       75%          90%          99%    Average%
# Age
# 17      $972   $3,013    $7,500   $17,610.00   $79,000.00   $7,761.47
# 18    $1,600   $6,000   $14,820   $25,001.00   $65,002.00  $10,753.50
# 19    $3,990  $11,515   $23,000   $35,000.00   $71,001.00  $15,640.00
# 20    $6,000  $16,479   $27,516   $40,000.00   $80,004.00  $19,526.09
# 21   $10,000  $20,000   $30,001   $41,820.00   $83,002.00  $22,363.58
# 22   $10,000  $20,000   $34,320   $50,000.00   $93,691.00  $24,706.00
# 23   $14,000  $25,000   $40,033   $60,101.00  $100,005.00  $30,118.12
# 24   $17,750  $30,000   $46,401   $65,000.00  $149,501.00  $36,054.20
# 25   $21,000  $35,000   $55,000   $76,011.00  $160,201.00  $42,943.11
# 26   $22,000  $38,000   $58,000   $86,102.00  $237,507.00  $47,873.45
# 27   $25,000  $41,001   $61,600   $91,800.00  $203,551.00  $50,298.65
# 28   $25,025  $42,002   $65,000  $100,100.00  $217,172.00  $54,221.10
# 29   $25,100  $45,000   $67,310  $100,400.00  $240,001.00  $54,718.76
# 30   $25,200  $45,003   $73,321  $108,530.00  $338,500.00  $59,818.59
# 31   $28,000  $45,704   $70,002  $111,100.00  $252,670.00  $57,537.18
# 32   $29,998  $48,002   $77,060  $120,500.00  $320,900.00  $63,165.08
# 33   $29,980  $49,000   $76,255  $120,202.00  $296,000.00  $62,046.62
# 34   $28,000  $50,000   $78,003  $122,210.00  $406,001.00  $66,313.13
# 35   $30,616  $52,776   $87,055  $133,504.00  $347,103.00  $71,388.71
# 36   $30,000  $52,010   $87,006  $131,131.00  $391,451.00  $71,345.70
# 37   $30,000  $52,103   $86,000  $137,060.00  $304,027.00  $69,504.62
# 38   $30,000  $52,000   $89,610  $150,110.00  $433,410.00  $74,890.28
# 39   $30,000  $53,100   $90,301  $145,000.00  $395,509.00  $74,456.32
# 40   $32,000  $54,896   $87,855  $140,669.00  $330,011.00  $71,525.01
# 41   $30,091  $53,119   $89,404  $150,012.00  $576,004.00  $75,906.69
